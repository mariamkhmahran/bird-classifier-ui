# %%
PATH_TO_RCNN = "faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"

# %%
PATH_TO_SSD = "ssd_resnet101_v1_fpn_1024x1024_coco17_tpu-8"

# %%
def evaluate(PATH_TO_MODEL):
    # !set CUDA_VISIBLE_DEVICES="-1" & python model_main_tf2.py --model_dir=training/TF2/training/{PATH_TO_MODEL} --pipeline_config_path=training/TF2/training/{PATH_TO_MODEL}/pipeline.config --SAMPLE_1_OF_N_EVAL_EXAMPLES=1 --checkpoint_dir=training/TF2/training/{PATH_TO_MODEL} --alsologtostderr

# %%
evaluate(PATH_TO_RCNN)
# Out:
# 2022-12-19 18:51:41.169502: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W1219 18:51:42.421645 139638172480320 model_lib_v2.py:1081] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I1219 18:51:42.421731 139638172480320 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1219 18:51:42.421779 139638172480320 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I1219 18:51:42.421821 139638172480320 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %%
evaluate(PATH_TO_SSD)
# Out:
# 2022-12-19 18:54:57.704984: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W1219 18:54:58.959098 139932065903424 model_lib_v2.py:1081] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I1219 18:54:58.959182 139932065903424 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1219 18:54:58.959225 139932065903424 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I1219 18:54:58.959263 139932065903424 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...
