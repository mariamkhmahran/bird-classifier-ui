# %% [markdown]
# <strong><center> ![image.png](attachment:64d92c28-b47b-4f94-8591-f1a5c0ec68d9.png) <strong><center>

# %% [markdown]
# <strong><center>Copyright by Paul Fergus & Carl Chalmers</center></strong>
# <strong><center>Created by BonsAI</center></strong>

# %% [markdown]
# ## Evaluation
#
# ## Runs the TensorFlow Evaluation script

# %%
# Set model path

PATH_TO_MODEL = "faster_rcnn_resnet101_v1_640x640_coco17_tpu-8"

# %%
# !CUDA_VISIBLE_DEVICES="" python model_main_tf2.py --pipeline_config_path=training/TF2/training/{PATH_TO_MODEL}/pipeline.config --model_dir=training/TF2/training/{PATH_TO_MODEL} --checkpoint_dir=training/TF2/training/{PATH_TO_MODEL} --alsologtostderr
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0908 08:40:39.686414 140316568954688 model_lib_v2.py:919] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0908 08:40:39.686528 140316568954688 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0908 08:40:39.686583 140316568954688 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0908 08:40:39.686619 140316568954688 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# ...

# %% [markdown]
# <strong><center> ![image.png](attachment:bc9616ad-ce18-46c2-821b-847b5f3fe7e2.png) <strong><center>
