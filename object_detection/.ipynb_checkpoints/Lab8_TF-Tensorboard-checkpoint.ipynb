# %% [markdown]
# <strong><center> ![image.png](attachment:0083f0d6-6079-4ea6-9942-ae9825128116.png) <strong><center>

# %% [markdown]
# <strong><center>Copyright by Paul Fergus & Carl Chalmers</center></strong>
# <strong><center>Created by BonsAI</center></strong>

# %% [markdown]
# ## Run Tensorboard

# %% [markdown]
# ## Set the model path

# %%
PATH_TO_MODEL = "faster_rcnn_resnet101_v1_640x640_coco17_tpu-8"

# %%
# !tensorboard --logdir=training/TF2/training/{PATH_TO_MODEL}/
# Out:
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.2.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# <strong><center> ![image.png](attachment:3d10ca79-c218-49c1-8e27-cda459d24e77.png) <strong><center>
