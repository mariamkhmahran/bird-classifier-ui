# %%
# !python xmlconversion.py --verbose
# Out:
# images/Car02.xml
# images/Car119.xml
# images/Car84.xml
# images/Car117.xml
# images/Car107.xml
# images/LoxodontaAfricana028.xml
# images/Car121.xml
# images/LoxodontaAfricana091.xml
# images/Car47.xml
# images/Car53.xml
# images/Car122.xml
# images/LoxodontaAfricana088.xml
# images/Car148.xml
# images/Car22.xml
# images/Car128.xml
# images/Car58.xml
# images/LoxodontaAfricana047.xml
# images/Car06.xml
# images/Car64.xml
# images/Car34.xml
# images/Car52.xml
# images/Car120.xml
# images/LoxodontaAfricana014.xml
# images/LoxodontaAfricana060.xml
# images/LoxodontaAfricana078.xml
# images/Car68.xml
# images/Car138.xml
# images/Car13.xml
# images/LoxodontaAfricana094.xml
# images/LoxodontaAfricana015.xml
# images/Car63.xml
# images/Car18.xml
# images/LoxodontaAfricana007.xml
# images/Car151.xml
# images/Car105.xml
# images/Car62.xml
# images/Car675.xml
# images/LoxodontaAfricana039.xml
# images/LoxodontaAfricana011.xml
# images/LoxodontaAfricana066.xml
# images/LoxodontaAfricana033.xml
# images/Car59.xml
# images/LoxodontaAfricana098.xml
# images/LoxodontaAfricana069.xml
# images/Car65.xml
# images/Car44.xml
# images/Car46.xml
# images/LoxodontaAfricana042.xml
# images/Car133.xml
# images/LoxodontaAfricana058.xml
# images/LoxodontaAfricana016.xml
# images/Car05.xml
# images/Car103.xml
# images/LoxodontaAfricana111.xml
# images/LoxodontaAfricana093.xml
# images/LoxodontaAfricana049.xml
# images/LoxodontaAfricana073.xml
# images/LoxodontaAfricana055.xml
# images/LoxodontaAfricana096.xml
# images/Car49.xml
# images/Car131.xml
# images/LoxodontaAfricana076.xml
# images/Car83.xml
# images/Car132.xml
# images/Car149.xml
# images/Car24.xml
# images/LoxodontaAfricana021.xml
# images/Car40.xml
# images/Car140.xml
# images/LoxodontaAfricana005.xml
# images/Car10.xml
# images/Car126.xml
# images/LoxodontaAfricana107.xml
# images/LoxodontaAfricana020.xml
# images/LoxodontaAfricana029.xml
# images/Car144.xml
# images/LoxodontaAfricana024.xml
# images/LoxodontaAfricana061.xml
# images/LoxodontaAfricana062.xml
# images/Car127.xml
# images/Car113.xml
# images/LoxodontaAfricana017.xml
# images/LoxodontaAfricana074.xml
# images/LoxodontaAfricana004.xml
# images/Car54.xml
# images/LoxodontaAfricana092.xml
# images/Car32.xml
# images/Car109.xml
# images/Car80.xml
# images/LoxodontaAfricana044.xml
# images/LoxodontaAfricana079.xml
# images/LoxodontaAfricana063.xml
# images/LoxodontaAfricana072.xml
# images/Car146.xml
# images/LoxodontaAfricana031.xml
# images/LoxodontaAfricana036.xml
# images/Car36.xml
# images/Car116.xml
# images/Car74.xml
# images/LoxodontaAfricana120.xml
# images/LoxodontaAfricana067.xml
# images/Car77.xml
# images/LoxodontaAfricana109.xml
# images/LoxodontaAfricana101.xml
# images/LoxodontaAfricana046.xml
# images/Car15.xml
# images/Car154.xml
# images/LoxodontaAfricana013.xml
# images/Car111.xml
# images/Car25.xml
# images/LoxodontaAfricana095.xml
# images/Car35.xml
# images/LoxodontaAfricana022.xml
# images/LoxodontaAfricana104.xml
# images/LoxodontaAfricana056.xml
# images/LoxodontaAfricana089.xml
# images/Car108.xml
# images/LoxodontaAfricana025.xml
# images/LoxodontaAfricana038.xml
# images/Car42.xml
# images/Car104.xml
# images/Car11.xml
# images/Car55.xml
# images/Car678.xml
# images/LoxodontaAfricana027.xml
# images/LoxodontaAfricana099.xml
# images/LoxodontaAfricana097.xml
# images/Car114.xml
# images/Car73.xml
# images/LoxodontaAfricana090.xml
# images/Car14.xml
# images/Car67.xml
# images/LoxodontaAfricana100.xml
# images/Car129.xml
# images/LoxodontaAfricana083.xml
# images/Car142.xml
# images/LoxodontaAfricana068.xml
# images/LoxodontaAfricana001.xml
# images/Car60.xml
# images/LoxodontaAfricana010.xml
# images/Car125.xml
# images/Car69.xml
# images/Car153.xml
# images/Car30.xml
# images/LoxodontaAfricana070.xml
# images/Car04.xml
# images/Car45.xml
# images/Car123.xml
# images/Car57.xml
# images/LoxodontaAfricana040.xml
# images/Car09.xml
# images/LoxodontaAfricana030.xml
# images/Car50.xml
# images/Car118.xml
# images/Car48.xml
# images/Car03.xml
# images/Car78.xml
# images/Car79.xml
# images/Car27.xml
# images/LoxodontaAfricana082.xml
# images/Car112.xml
# images/LoxodontaAfricana045.xml
# images/LoxodontaAfricana085.xml
# images/Car56.xml
# images/LoxodontaAfricana054.xml
# images/LoxodontaAfricana050.xml
# images/Car75.xml
# images/Car70.xml
# images/Car145.xml
# images/Car31.xml
# images/LoxodontaAfricana112.xml
# images/LoxodontaAfricana035.xml
# images/Car139.xml
# images/LoxodontaAfricana113.xml
# images/LoxodontaAfricana086.xml
# images/Car130.xml
# images/Car26.xml
# images/Car106.xml
# images/LoxodontaAfricana102.xml
# images/Car16.xml
# images/LoxodontaAfricana105.xml

# %%
# !python partition_dataset.py -x -i ./images -r 0.1

# %%
# !code './data/label_map.pbtxt'

# %%
# !python generate_tfrecord.py -x images/train -l data/label_map.pbtxt -o data/train.record
# Out:
# Successfully created the TFRecord file: data/train.record

# %%
# !python generate_tfrecord.py -x images/test -l data/label_map.pbtxt -o data/test.record
# Out:
# Successfully created the TFRecord file: data/test.record

# %%
PATH_TO_MODEL = "faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8"

# %%
# !code './training/TF2/training/'{PATH_TO_MODEL}'/pipeline.config'

# %%
# !python model_main_tf2.py --model_dir=training/TF2/training/{PATH_TO_MODEL} --pipeline_config_path=training/TF2/training/{PATH_TO_MODEL}/pipeline.config --num_train_steps=5000 --alsologtostderr
# Out:
# 2022-12-05 14:02:55.046516: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-12-05 14:02:56.479457: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-12-05 14:02:56.509727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:02:56.510235: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.755GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2022-12-05 14:02:56.510259: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-12-05 14:02:56.517394: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-12-05 14:02:56.517445: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-12-05 14:02:56.520160: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-12-05 14:02:56.521656: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-12-05 14:02:56.523512: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-12-05 14:02:56.525550: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-12-05 14:02:56.525915: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-12-05 14:02:56.525992: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:02:56.526509: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:02:56.527099: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-12-05 14:02:56.527541: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-05 14:02:56.528033: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:02:56.528488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.755GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2022-12-05 14:02:56.528537: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:02:56.529015: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:02:56.529458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-12-05 14:02:56.529681: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-12-05 14:02:56.995949: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-05 14:02:56.995968: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2022-12-05 14:02:56.995975: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2022-12-05 14:02:56.996103: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:02:56.996606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:02:56.997072: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:02:56.997513: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22280 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6)
# WARNING:tensorflow:Collective ops is not configured at program startup. Some performance features may not be enabled.
# W1205 14:02:56.999715 140613220172608 mirrored_strategy.py:379] Collective ops is not configured at program startup. Some performance features may not be enabled.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I1205 14:02:57.155733 140613220172608 mirrored_strategy.py:369] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: 5000
# I1205 14:02:57.157704 140613220172608 config_util.py:552] Maybe overwriting train_steps: 5000
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I1205 14:02:57.157769 140613220172608 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/object_detection/model_lib_v2.py:557: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W1205 14:02:57.172773 140613220172608 deprecation.py:330] From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/object_detection/model_lib_v2.py:557: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['data/train.record']
# I1205 14:02:57.175536 140613220172608 dataset_builder.py:163] Reading unweighted datasets: ['data/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['data/train.record']
# I1205 14:02:57.175617 140613220172608 dataset_builder.py:80] Reading record datasets for input file: ['data/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I1205 14:02:57.175657 140613220172608 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W1205 14:02:57.175689 140613220172608 dataset_builder.py:87] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W1205 14:02:57.177953 140613220172608 deprecation.py:330] From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:101: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W1205 14:02:57.190743 140613220172608 deprecation.py:330] From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/object_detection/builders/dataset_builder.py:236: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W1205 14:03:00.780273 140613220172608 deprecation.py:330] From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W1205 14:03:03.166834 140613220172608 deprecation.py:330] From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:464: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# 2022-12-05 14:03:04.329194: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-12-05 14:03:04.349850: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 3699850000 Hz
# /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:435: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# INFO:tensorflow:depth of additional conv before box predictor: 0
# I1205 14:03:08.602380 140577618253568 convolutional_keras_box_predictor.py:153] depth of additional conv before box predictor: 0
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:464: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# W1205 14:03:12.143884 140577618253568 deprecation.py:330] From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:464: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# W1205 14:03:14.594401 140577618253568 deprecation.py:330] From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:206: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# 2022-12-05 14:03:20.605876: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-12-05 14:03:21.105525: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8100
# 2022-12-05 14:03:21.868419: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-12-05 14:03:22.398906: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-12-05 14:03:22.536227: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.238224 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.238726 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.239627 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.240024 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.240941 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.241338 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.242421 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.242819 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.243554 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I1205 14:03:24.243955 140613220172608 cross_device_ops.py:619] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:602: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W1205 14:03:24.774233 140577626646272 deprecation.py:528] From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/util/deprecation.py:602: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 0.360s
# I1205 14:04:00.550875 140613220172608 model_lib_v2.py:698] Step 100 per-step time 0.360s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.54478526,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/objectness_loss': 0.43958876,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.98437405,
#  'learning_rate': 5.7999998e-05}
# I1205 14:04:00.551040 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.54478526,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/objectness_loss': 0.43958876,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.98437405,
#  'learning_rate': 5.7999998e-05}
# INFO:tensorflow:Step 200 per-step time 0.107s
# I1205 14:04:11.237107 140613220172608 model_lib_v2.py:698] Step 200 per-step time 0.107s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.48212454,
#  'Loss/BoxClassifierLoss/localization_loss': 1.0670686,
#  'Loss/RPNLoss/localization_loss': 0.21911986,
#  'Loss/RPNLoss/objectness_loss': 0.2917984,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.0601113,
#  'learning_rate': 7.6e-05}
# I1205 14:04:11.237252 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.48212454,
#  'Loss/BoxClassifierLoss/localization_loss': 1.0670686,
#  'Loss/RPNLoss/localization_loss': 0.21911986,
#  'Loss/RPNLoss/objectness_loss': 0.2917984,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.0601113,
#  'learning_rate': 7.6e-05}
# INFO:tensorflow:Step 300 per-step time 0.107s
# I1205 14:04:21.937431 140613220172608 model_lib_v2.py:698] Step 300 per-step time 0.107s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.6033038,
#  'Loss/BoxClassifierLoss/localization_loss': 1.4159098,
#  'Loss/RPNLoss/localization_loss': 0.169458,
#  'Loss/RPNLoss/objectness_loss': 0.24950723,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.4381788,
#  'learning_rate': 9.4e-05}
# I1205 14:04:21.937579 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.6033038,
#  'Loss/BoxClassifierLoss/localization_loss': 1.4159098,
#  'Loss/RPNLoss/localization_loss': 0.169458,
#  'Loss/RPNLoss/objectness_loss': 0.24950723,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 2.4381788,
#  'learning_rate': 9.4e-05}
# INFO:tensorflow:Step 400 per-step time 0.107s
# I1205 14:04:32.661587 140613220172608 model_lib_v2.py:698] Step 400 per-step time 0.107s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.22980894,
#  'Loss/BoxClassifierLoss/localization_loss': 0.19369027,
#  'Loss/RPNLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/objectness_loss': 0.06260661,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.48610583,
#  'learning_rate': 0.000112}
# I1205 14:04:32.661730 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.22980894,
#  'Loss/BoxClassifierLoss/localization_loss': 0.19369027,
#  'Loss/RPNLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/objectness_loss': 0.06260661,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.48610583,
#  'learning_rate': 0.000112}
# INFO:tensorflow:Step 500 per-step time 0.107s
# I1205 14:04:43.372389 140613220172608 model_lib_v2.py:698] Step 500 per-step time 0.107s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.13654122,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.35301283,
#  'Loss/RPNLoss/objectness_loss': 0.26524544,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7547995,
#  'learning_rate': 0.00013}
# I1205 14:04:43.372533 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.13654122,
#  'Loss/BoxClassifierLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/localization_loss': 0.35301283,
#  'Loss/RPNLoss/objectness_loss': 0.26524544,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.7547995,
#  'learning_rate': 0.00013}
# INFO:tensorflow:Step 600 per-step time 0.107s
# I1205 14:04:54.101490 140613220172608 model_lib_v2.py:698] Step 600 per-step time 0.107s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.21359973,
#  'Loss/BoxClassifierLoss/localization_loss': 0.42785692,
#  'Loss/RPNLoss/localization_loss': 0.09559115,
#  'Loss/RPNLoss/objectness_loss': 0.27396867,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0110165,
#  'learning_rate': 0.00014799999}
# I1205 14:04:54.101635 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.21359973,
#  'Loss/BoxClassifierLoss/localization_loss': 0.42785692,
#  'Loss/RPNLoss/localization_loss': 0.09559115,
#  'Loss/RPNLoss/objectness_loss': 0.27396867,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0110165,
#  'learning_rate': 0.00014799999}
# INFO:tensorflow:Step 700 per-step time 0.107s
# I1205 14:05:04.828094 140613220172608 model_lib_v2.py:698] Step 700 per-step time 0.107s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.08544299,
#  'Loss/BoxClassifierLoss/localization_loss': 0.17612877,
#  'Loss/RPNLoss/localization_loss': 0.20187679,
#  'Loss/RPNLoss/objectness_loss': 0.6217242,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0851728,
#  'learning_rate': 0.000166}
# I1205 14:05:04.828249 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.08544299,
#  'Loss/BoxClassifierLoss/localization_loss': 0.17612877,
#  'Loss/RPNLoss/localization_loss': 0.20187679,
#  'Loss/RPNLoss/objectness_loss': 0.6217242,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0851728,
#  'learning_rate': 0.000166}
# INFO:tensorflow:Step 800 per-step time 0.107s
# I1205 14:05:15.534993 140613220172608 model_lib_v2.py:698] Step 800 per-step time 0.107s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.26608473,
#  'Loss/BoxClassifierLoss/localization_loss': 0.49029812,
#  'Loss/RPNLoss/localization_loss': 0.11463831,
#  'Loss/RPNLoss/objectness_loss': 0.20547722,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0764984,
#  'learning_rate': 0.000184}
# I1205 14:05:15.535136 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.26608473,
#  'Loss/BoxClassifierLoss/localization_loss': 0.49029812,
#  'Loss/RPNLoss/localization_loss': 0.11463831,
#  'Loss/RPNLoss/objectness_loss': 0.20547722,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 1.0764984,
#  'learning_rate': 0.000184}
# INFO:tensorflow:Step 900 per-step time 0.107s
# I1205 14:05:26.258933 140613220172608 model_lib_v2.py:698] Step 900 per-step time 0.107s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.11404103,
#  'Loss/BoxClassifierLoss/localization_loss': 0.23529525,
#  'Loss/RPNLoss/localization_loss': 0.15919438,
#  'Loss/RPNLoss/objectness_loss': 0.12051579,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.62904644,
#  'learning_rate': 0.000202}
# I1205 14:05:26.259085 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.11404103,
#  'Loss/BoxClassifierLoss/localization_loss': 0.23529525,
#  'Loss/RPNLoss/localization_loss': 0.15919438,
#  'Loss/RPNLoss/objectness_loss': 0.12051579,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.62904644,
#  'learning_rate': 0.000202}
# INFO:tensorflow:Step 1000 per-step time 0.107s
# I1205 14:05:36.982421 140613220172608 model_lib_v2.py:698] Step 1000 per-step time 0.107s
# INFO:tensorflow:{'Loss/BoxClassifierLoss/classification_loss': 0.12659925,
#  'Loss/BoxClassifierLoss/localization_loss': 0.083537035,
#  'Loss/RPNLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/objectness_loss': 0.05176803,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.26190433,
#  'learning_rate': 0.00022}
# I1205 14:05:36.982582 140613220172608 model_lib_v2.py:701] {'Loss/BoxClassifierLoss/classification_loss': 0.12659925,
#  'Loss/BoxClassifierLoss/localization_loss': 0.083537035,
#  'Loss/RPNLoss/localization_loss': 0.0,
#  'Loss/RPNLoss/objectness_loss': 0.05176803,
#  'Loss/regularization_loss': 0.0,
#  'Loss/total_loss': 0.26190433,
#  'learning_rate': 0.00022}
# ^C

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path ./training/TF2/training/{PATH_TO_MODEL}/pipeline.config --trained_checkpoint_dir ./training/TF2/training/{PATH_TO_MODEL}/ --output_directory ./training/TF2/training/{PATH_TO_MODEL}/saved_model/
# Out:
# 2022-12-05 14:05:45.323576: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-12-05 14:05:46.406923: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-12-05 14:05:46.451081: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:05:46.451522: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.755GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2022-12-05 14:05:46.451539: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-12-05 14:05:46.453000: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-12-05 14:05:46.453028: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-12-05 14:05:46.453500: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-12-05 14:05:46.453613: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-12-05 14:05:46.454079: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-12-05 14:05:46.454479: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-12-05 14:05:46.454549: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-12-05 14:05:46.454594: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:05:46.455040: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:05:46.455454: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-12-05 14:05:46.455669: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-05 14:05:46.456229: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:05:46.456650: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 3090 computeCapability: 8.6
# coreClock: 1.755GHz coreCount: 82 deviceMemorySize: 23.70GiB deviceMemoryBandwidth: 871.81GiB/s
# 2022-12-05 14:05:46.456691: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:05:46.457126: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:05:46.457534: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-12-05 14:05:46.457553: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-12-05 14:05:46.732897: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-12-05 14:05:46.732915: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2022-12-05 14:05:46.732920: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2022-12-05 14:05:46.733031: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:05:46.733496: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:05:46.733954: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-05 14:05:46.734380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22280 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6)
# WARNING:tensorflow:From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W1205 14:05:47.024975 140690182669120 deprecation.py:596] From /home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py:463: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# ^C
# Traceback (most recent call last):
#   File "exporter_main_v2.py", line 126, in <module>
#     app.run(main)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "exporter_main_v2.py", line 120, in main
#     exporter_lib_v2.export_inference_graph(
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/object_detection/exporter_lib_v2.py", line 271, in export_inference_graph
#     concrete_function = detection_module.__call__.get_concrete_function()
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 1367, in get_concrete_function
#     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 1273, in _get_concrete_function_garbage_collected
#     self._initialize(args, kwargs, add_initializers_to=initializers)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 763, in _initialize
#     self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3050, in _get_concrete_function_internal_garbage_collected
#     graph_function, _ = self._maybe_define_function(args, kwargs)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3444, in _maybe_define_function
#     graph_function = self._create_graph_function(args, kwargs)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/eager/function.py", line 3279, in _create_graph_function
#     func_graph_module.func_graph_from_py_func(
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 999, in func_graph_from_py_func
#     func_outputs = python_func(*func_args, **func_kwargs)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py", line 672, in wrapped_fn
#     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py", line 975, in wrapper
#     return autograph.converted_call(
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 444, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/tmp1yp49fnr.py", line 15, in tf__call_func
#     retval_ = ag__.converted_call(ag__.ld(self)._run_inference_on_images, (ag__.ld(images), ag__.ld(true_shapes)), dict(**ag__.ld(kwargs)), fscope)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 444, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/tmpgrcr9w10.py", line 12, in tf___run_inference_on_images
#     prediction_dict = ag__.converted_call(ag__.ld(self)._model.predict, (ag__.ld(images), ag__.ld(true_shapes)), dict(**ag__.ld(kwargs)), fscope)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 444, in converted_call
#     result = converted_f(*effective_args, **kwargs)
#   File "/tmp/tmpkbip8uqy.py", line 12, in tf__predict
#     prediction_dict = ag__.converted_call(ag__.ld(self)._predict_first_stage, (ag__.ld(preprocessed_inputs),), None, fscope)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 446, in converted_call
#     result = converted_f(*effective_args)
#   File "/tmp/tmp27p_q2_j.py", line 12, in tf___predict_first_stage
#     (rpn_box_predictor_features, rpn_features_to_crop, anchors_boxlist, image_shape) = ag__.converted_call(ag__.ld(self)._extract_rpn_feature_maps, (ag__.ld(preprocessed_inputs),), None, fscope)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 446, in converted_call
#     result = converted_f(*effective_args)
#   File "/tmp/tmpyvsp4xsw.py", line 13, in tf___extract_rpn_feature_maps
#     (rpn_features_to_crop, ag__.ld(self).endpoints) = ag__.converted_call(ag__.ld(self)._extract_proposal_features, (ag__.ld(preprocessed_inputs),), None, fscope)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/impl/api.py", line 446, in converted_call
#     result = converted_f(*effective_args)
#   File "/tmp/tmpkairrdu7.py", line 23, in tf___extract_proposal_features
#     ag__.if_stmt((ag__.ld(self)._feature_extractor_for_proposal_features == ag__.ld(_UNINITIALIZED_FEATURE_EXTRACTOR)), if_body, else_body, get_state, set_state, ('self._feature_extractor_for_proposal_features',), 1)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py", line 1172, in if_stmt
#     _py_if_stmt(cond, body, orelse)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/autograph/operators/control_flow.py", line 1225, in _py_if_stmt
#     return body() if cond else orelse()
#   File "/tmp/tmpkairrdu7.py", line 19, in if_body
#     ag__.ld(self)._feature_extractor_for_proposal_features = ag__.converted_call(ag__.ld(self)._feature_extractor.get_proposal_feature_extractor_model, (), dict(name=ag__.ld(self).first_stage_feature_extractor_scope), fscope)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2752, in __setattr__
#     value = data_structures.sticky_attribute_assignment(
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/training/tracking/data_structures.py", line 153, in sticky_attribute_assignment
#     trackable._track_trackable(  # pylint: disable=protected-access
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py", line 914, in _track_trackable
#     self._handle_deferred_dependencies(name=name, trackable=trackable)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py", line 947, in _handle_deferred_dependencies
#     checkpoint_position.restore(trackable)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py", line 258, in restore
#     restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py", line 969, in _restore_from_checkpoint_position
#     current_position.trackable  # pylint: disable=protected-access
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/training/tracking/base.py", line 1000, in _single_restoration_from_checkpoint_position
#     local_object = self._lookup_dependency(child.local_name)
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py", line 375, in _lookup_dependency
#     layer_dependencies = self._layer_checkpoint_dependencies
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py", line 350, in _layer_checkpoint_dependencies
#     if layer.weights:
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1326, in weights
#     return self.trainable_weights + self.non_trainable_weights
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py", line 1293, in trainable_weights
#     children_weights = self._gather_children_attribute('trainable_variables')
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2816, in _gather_children_attribute
#     return list(
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2817, in <genexpr>
#     itertools.chain.from_iterable(
#   File "/home/msc1/anaconda3/envs/Object-Detection-API/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py", line 2862, in _flatten_modules
#     elif isinstance(trackable_obj, data_structures.TrackableDataStructure):
# KeyboardInterrupt

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import pathlib
import tensorflow as tf

tf.get_logger().setLevel('ERROR')
# Suppress TensorFlow logging (1)
# Suppress TensorFlow logging (2)
# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
IMAGE_PATHS = 'test_images/'

# %%
PATH_TO_MODEL_DIR = './training/TF2/training/' + PATH_TO_MODEL + '/saved_model/saved_model/'
PATH_TO_MODEL_DIR
# Out:
# './training/TF2/training/faster_rcnn_resnet101_v1_1024x1024_coco17_tpu-8/saved_model/saved_model/'

# %%
PATH_TO_LABELS = './data/label_map.pbtxt'

# %%
import time
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils
PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR
print('Loading model...', end='')
start_time = time.time()
# Load saved model and build the detection function
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)
end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))
# Out:
# Loading model...Done! Took 8.593104124069214 seconds

# %%
category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS, use_display_name=True)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
import os
warnings.filterwarnings('ignore')
# Suppress Matplotlib warnings
def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.
    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.
    Args:
    path: the file path to the image
    Returns:
    uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))

for image_path in os.listdir(IMAGE_PATHS):
    image_path = os.path.join(IMAGE_PATHS, image_path)
    print('Running inference for {}... '.format(image_path), end='')
    image_np = load_image_into_numpy_array(image_path)
    # Things to try:
    # Flip horizontally
    # image_np = np.fliplr(image_np).copy()
    # Convert image to grayscale
    # image_np = np.tile(
    #
    # np.mean(image_np, 2, keepdims=True), (1, 1, 3)).astype(np.uint8)
    # The input needs to be a tensor, convert it using `tf.convert_to_tensor`
    input_tensor = tf.convert_to_tensor(image_np)
    # The model expects a batch of images, so add an axis with `tf.newaxis`.
    input_tensor = input_tensor[tf.newaxis, ...]
    # input_tensor = np.expand_dims(image_np, 0)
    detections = detect_fn(input_tensor)
    # All outputs are batches tensors.
    # Convert to numpy arrays, and take index [0] to remove the batch dimensi
    # We're only interested in the first num_detections.
    num_detections = int(detections.pop('num_detections'))
    detections = {key: value[0, :num_detections].numpy() for key, value in detections.items()}
    detections['num_detections'] = num_detections
    # detection_classes should be ints.
    detections['detection_classes'] = detections['detection_classes'].astype(int)
    image_np_with_detections = image_np.copy()
    viz_utils.visualize_boxes_and_labels_on_image_array(
        image_np_with_detections,
        detections['detection_boxes'],
        detections['detection_classes'],
        detections['detection_scores'],
        category_index,
        use_normalized_coordinates=True,
        max_boxes_to_draw=200,
        min_score_thresh=0.60,
        agnostic_mode=False)
    plt.figure()
    plt.imshow(image_np_with_detections)
    print('Done')
plt.show()
# Out:
# Running inference for test_images/Car1.jpg... Done
# Running inference for test_images/Elephant2.jpg... Done
# Running inference for test_images/Car2.jpg... Done
# Running inference for test_images/Elephant1.jpg... Done
